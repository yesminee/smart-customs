# %% [markdown]
# <a href="https://colab.research.google.com/github/yesminee/smart-customs/blob/main/Copie_de_Zindi_Feature_Engineering_Tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Target Encoding using "Traffic Jam: Predicting People's Movement into Nairobi data"
# Categorical variables take on a limited, fixed number of values, assigning each individual/unit to a particular group on the basis of a qualitative property. Dealing with categorical data is inevitable when you’re doing supervised learning. However, most machine learning algorithms require numerical input data. In this case, converting categorical variables to numerical variables is essential.
# There are many ways to do so:
# * Label Encoding where you represent each category with a random number,
# * One-hot encoding where you create one binary column per category,
# * Target encoding where you calculate some statistical measures such as the mean, max,min etc. of the target value by category.
#
# In this notebook we will focus on the target encoding technique to transform categorical data.

# %% [markdown]
# ## Target Encoding
#
# ### Import required libraries

# %%
import pandas as pd  
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns
from sklearn.model_selection import train_test_split,KFold
import xgboost as xgb
from sklearn.metrics import mean_absolute_error

# %% [markdown]
# ###Load the data

# %%
train=pd.read_csv("./Data/train.zip")
test=pd.read_csv("./Data/test.csv")

# %% [markdown]
# ### Step 1: Create the train set. The data contains categorical information about ticket transactions, we need to group it by ride_id to find the right number of tickets per ride.

# %%
Target=train.groupby(["ride_id"]).seat_number.count().rename("number_of_ticket").reset_index()
train=train.drop_duplicates("ride_id").drop(['payment_method', 'payment_receipt', 'seat_number'],axis=1)
train=train.merge(Target,how="left",on="ride_id")

train.drop(["travel_to"],axis=1,inplace=True)
test.drop(["travel_to"],axis=1,inplace=True)

# %%
train.head() booo

# %%
test.head()

# %% [markdown]
# ### Step 2: Process the date columns and add time features

# %%
def add_20(x):
    date=x.split("-")
    date[-1]="20"+date[-1]
    return "-".join(date)
train["date"]=(train["travel_date"].apply(add_20)+" "+train["travel_time"]).astype(str)
test["date"]=(test["travel_date"]+" "+test["travel_time"]).astype(str)

# %%
def  time_features(x): 
    x["date"]=pd.to_datetime(x["date"],format='%d-%m-%Y %H:%M')
    x["dayofweek"]=x["date"].dt.dayofweek
    x["dayofyear"]=x["date"].dt.dayofyear
    x["dayofmonth"]=x["date"].dt.day
    x["year_woy"]=x["date"].dt.year.astype(str)+x["date"].dt.weekofyear.astype(str)
    x["hour"]=x["date"].dt.hour
    x["minute"]=x["date"].dt.minute
    x["is_weekend"]=x["dayofweek"].apply( lambda x : 1 if x  in [5,6] else 0 )
    x["year"]=x["date"].dt.year
    x["quarter"]=x["date"].dt.quarter
    x["month"]=x["date"].dt.month
    

    return x 
train=time_features(train)

# %%
def  time_features(x): 
    x["date"]=pd.to_datetime(x["date"],format='%Y-%m-%d %H:%M')
    x["dayofweek"]=x["date"].dt.dayofweek
    x["hour"]=x["date"].dt.hour
    x["minute"]=x["date"].dt.minute
    x["dayofyear"]=x["date"].dt.dayofyear
    x["dayofmonth"]=x["date"].dt.day
    x["is_weekend"]=x["dayofweek"].apply( lambda x : 1 if x  in [5,6] else 0 )
    x["year_woy"]=x["date"].dt.year.astype(str)+x["date"].dt.weekofyear.astype(str)
    x["year"]=x["date"].dt.year
    x["quarter"]=x["date"].dt.quarter
    x["month"]=x["date"].dt.month
    return x 
test=time_features(test)

# %%
test.head()

# %%
train.head()

# %% [markdown]
# ### Step 3: Select all categorical features

# %%
categorical_feautres=["travel_from","car_type","dayofweek","dayofmonth","hour","minute","year"]

# %%
def plot_categorical_feature(feautre):
    fig, axes = plt.subplots(nrows=1, ncols=2)
    train.groupby(feautre).number_of_ticket.mean().plot(kind="bar",ax=axes[0],figsize=(20,5),title="mean of number_of_ticket per {}".format(feautre))
    train.groupby(feautre).number_of_ticket.count().plot(kind="bar",ax=axes[1],figsize=(20,5),title="ride count per {}".format(feautre))    
    plt.show()
for feautre in categorical_feautres : 
    plot_categorical_feature(feautre)

# %% [markdown]
# ### Step 4: Define a function which takes a data frame, the name of the categorical feature, the name of the target column and statistical functions as inputs and returns an aggregate data frame grouped by the categorical feature

# %%
def target_encoding(data,feautre,target="number_of_ticket",agg_functions={"mean","std"}):
    agg=data.groupby(feautre)[target].agg(agg_functions)
    agg.columns=[column+"_per_{}_{}".format(feautre,target) for column in  agg.columns.tolist()]
    return agg

# %%
target_encoding(train,"dayofweek","number_of_ticket",{"mean","min","max","median"})
# Out:
#            max_per_dayofweek_number_of_ticket  \
# dayofweek
# 0                                          49
# 1                                          50
# 2                                          49
# 3                                          48
# 4                                          47
# 5                                          48
# 6                                          47
#
#            min_per_dayofweek_number_of_ticket  \
# dayofweek
# 0                                           1
# 1                                           1
# 2                                           1
# 3                                           1
# 4                                           1
# 5                                           1
# 6                                           1
#
#            median_per_dayofweek_number_of_ticket  \
# dayofweek
# 0                                              6
# 1                                              7
# 2                                              7
# 3                                              7
# 4                                              8
# 5                                              3
# 6                                              7
#
#            mean_per_dayofweek_number_of_ticket
# dayofweek
# 0                                     8.409198
# 1                                     8.475145
# 2                                     8.192585
# 3                                     8.137113
# 4                                     8.675573
# 5                                     7.101124
# 6                                     8.462121

# %%
train_TE=train.copy()
test_TE=test.copy()

# %% [markdown]
# ### Step 5:  Define another helper function to calculate the aggregate data frame for each categorical feature and join them with the train and test sets.
#
# #### *First target encoding apporach *

# %%
def add_target_encoding_features(train,test):
    for feautre in categorical_feautres : 
        agg=target_encoding(train,feautre)
        train=train.merge(agg,how="left",on=feautre)
        test=test.merge(agg,how="left",on=feautre)
    return train,test
train_TE,test_TE=add_target_encoding_features(train_TE,test_TE)

# %% [markdown]
# In many cases when you use the whole train set to calculate the aggregate features you will end up with a good score with the training and validation set and a bad score with the test set (overfitting), due to strong correlation between the new generated features and the target in the train set.
# To avoid this problem we should split the train data to new train and validation sets from the start and calculate the aggregate features using only the new train. We join it later with the validation set and the test set. Then we compare the score of the training and the validation to know if the  aggregate features are overfitting or not.
#
# #### *Second target encoding apporach *

# %%
train_VTE,val_VTE=train_test_split(train,random_state=1994,test_size=0.1)
test_VTE=test.copy()

# %%
def add_target_encoding_features_validation(train,val,test):
    for feautre in categorical_feautres : 
        agg=target_encoding(train,feautre)
        train=train.merge(agg,how="left",on=feautre)
        val=val.merge(agg,how="left",on=feautre)
        test=test.merge(agg,how="left",on=feautre)
        
    return train,val,test

# %%
train_VTE,val_VTE,test_VTE=add_target_encoding_features_validation(train_VTE,val_VTE,test_VTE)

# %%
train_VTE.head()
# Out:
#    ride_id travel_date travel_time travel_from car_type  max_capacity  \
# 0    11338    14-12-17        8:50       Kisii  shuttle            11
# 1    10431    28-12-17       10:58       Kisii  shuttle            11
# 2     8709    16-01-18        7:04    Homa Bay      Bus            49
# 3    11961    06-12-17        9:10       Kisii  shuttle            11
# 4     7954    21-12-17        7:11    Homa Bay      Bus            49
#
#    number_of_ticket                date  dayofweek  dayofyear  \
# 0                11 2017-12-14 08:50:00          3        348
# 1                 1 2017-12-28 10:58:00          3        362
# 2                31 2018-01-16 07:04:00          1         16
# 3                11 2017-12-06 09:10:00          2        340
# 4                 2 2017-12-21 07:11:00          3        355
#
#                 ...                std_per_dayofweek_number_of_ticket  \
# 0               ...                                          8.179312
# 1               ...                                          8.179312
# 2               ...                                          8.355861
# 3               ...                                          8.732400
# 4               ...                                          8.179312
#
#   mean_per_dayofweek_number_of_ticket  std_per_dayofmonth_number_of_ticket  \
# 0                            8.160000                             8.491308
# 1                            8.160000                             7.427756
# 2                            8.355007                             9.546244
# 3                            8.234357                             8.536107
# 4                            8.160000                             8.840447
#
#    mean_per_dayofmonth_number_of_ticket  std_per_hour_number_of_ticket  \
# 0                              8.873362                       4.768677
# 1                              8.105263                       3.768129
# 2                              8.502304                       9.775881
# 3                              8.736318                       3.645320
# 4                              8.278788                       9.775881
#
#    mean_per_hour_number_of_ticket  std_per_minute_number_of_ticket  \
# 0                        7.965844                         3.912548
# 1                        7.502762                         4.354656
# 2                        9.195509                         9.631956
# 3                        7.575342                         4.394825
# 4                        9.195509                         4.414732
#
#    mean_per_minute_number_of_ticket  std_per_year_number_of_ticket  \
# 0                          6.618321                       7.836962
# 1                          6.485714                       7.836962
# 2                          9.709360                       8.866694
# 3                          6.015590                       7.836962
# 4                          3.400000                       7.836962
#
#    mean_per_year_number_of_ticket
# 0                        8.318367
# 1                        8.318367
# 2                        8.265286
# 3                        8.318367
# 4                        8.318367
#
# [5 rows x 32 columns]

# %%
val_VTE.head()
# Out:
#    ride_id travel_date travel_time travel_from car_type  max_capacity  \
# 0     5897    12-04-18        5:20       Kisii  shuttle            11
# 1    12649    29-11-17        6:20       Kisii  shuttle            11
# 2    11774    06-03-18        7:06      Keroka      Bus            49
# 3    11064    22-02-18        5:50     Kijauri  shuttle            11
# 4    12316    16-03-18        7:10    Homa Bay      Bus            49
#
#    number_of_ticket                date  dayofweek  dayofyear  \
# 0                11 2018-04-12 05:20:00          3        102
# 1                 2 2017-11-29 06:20:00          2        333
# 2                 1 2018-03-06 07:06:00          1         65
# 3                 2 2018-02-22 05:50:00          3         53
# 4                 1 2018-03-16 07:10:00          4         75
#
#                 ...                std_per_dayofweek_number_of_ticket  \
# 0               ...                                          8.179312
# 1               ...                                          8.732400
# 2               ...                                          8.355861
# 3               ...                                          8.179312
# 4               ...                                          8.387088
#
#   mean_per_dayofweek_number_of_ticket  std_per_dayofmonth_number_of_ticket  \
# 0                            8.160000                             8.518181
# 1                            8.234357                             7.624334
# 2                            8.355007                             8.536107
# 3                            8.160000                             6.987652
# 4                            8.779082                             9.546244
#
#    mean_per_dayofmonth_number_of_ticket  std_per_hour_number_of_ticket  \
# 0                              8.807860                       3.483794
# 1                              7.881250                       4.067445
# 2                              8.736318                       9.775881
# 3                              7.639053                       3.483794
# 4                              8.502304                       9.775881
#
#    mean_per_hour_number_of_ticket  std_per_minute_number_of_ticket  \
# 0                        3.058691                         4.012592
# 1                        4.840909                         4.012592
# 2                        9.195509                         7.884698
# 3                        3.058691                         3.912548
# 4                        9.195509                         4.394825
#
#    mean_per_minute_number_of_ticket  std_per_year_number_of_ticket  \
# 0                          6.573333                       8.866694
# 1                          6.573333                       7.836962
# 2                          6.085911                       8.866694
# 3                          6.618321                       8.866694
# 4                          6.015590                       8.866694
#
#    mean_per_year_number_of_ticket
# 0                        8.265286
# 1                        8.318367
# 2                        8.265286
# 3                        8.265286
# 4                        8.265286
#
# [5 rows x 32 columns]

# %%
test_VTE.head()
# Out:
#    ride_id travel_date travel_time travel_from car_type  max_capacity  \
# 0      247  2018-05-07       07:06       Kisii      Bus            49
# 1      256  2018-05-06       11:08       Kisii  shuttle            11
# 2      275  2018-05-04       05:00       Kisii  shuttle            11
# 3      285  2018-05-04       09:10       Kisii  shuttle            11
# 4      286  2018-05-04       09:20       Kisii  shuttle            11
#
#                  date  dayofweek  hour  minute  \
# 0 2018-05-07 07:06:00          0     7       6
# 1 2018-05-06 11:08:00          6    11       8
# 2 2018-05-04 05:00:00          4     5       0
# 3 2018-05-04 09:10:00          4     9      10
# 4 2018-05-04 09:20:00          4     9      20
#
#                 ...                std_per_dayofweek_number_of_ticket  \
# 0               ...                                          8.935214
# 1               ...                                          8.550053
# 2               ...                                          8.387088
# 3               ...                                          8.387088
# 4               ...                                          8.387088
#
#    mean_per_dayofweek_number_of_ticket  std_per_dayofmonth_number_of_ticket  \
# 0                             8.342484                             8.926552
# 1                             8.516206                             8.536107
# 2                             8.779082                             8.619692
# 3                             8.779082                             8.619692
# 4                             8.779082                             8.619692
#
#   mean_per_dayofmonth_number_of_ticket  std_per_hour_number_of_ticket  \
# 0                             8.537445                       9.775881
# 1                             8.736318                       3.837963
# 2                             8.004444                       3.483794
# 3                             8.004444                       3.645320
# 4                             8.004444                       3.645320
#
#    mean_per_hour_number_of_ticket  std_per_minute_number_of_ticket  \
# 0                        9.195509                         7.884698
# 1                        7.253165                         8.078795
# 2                        3.058691                         7.554865
# 3                        7.575342                         4.394825
# 4                        7.575342                         4.012592
#
#    mean_per_minute_number_of_ticket  std_per_year_number_of_ticket  \
# 0                          6.085911                       8.866694
# 1                          9.019737                       8.866694
# 2                          6.883387                       8.866694
# 3                          6.015590                       8.866694
# 4                          6.573333                       8.866694
#
#    mean_per_year_number_of_ticket
# 0                        8.265286
# 1                        8.265286
# 2                        8.265286
# 3                        8.265286
# 4                        8.265286
#
# [5 rows x 31 columns]

# %% [markdown]
# #### *Third target encoding apporach *
# There is another way to do so by using K fold split.

# %%
def add_target_encoding_features_Kfold(train,test,split=10):
    kf = KFold(n_splits=split,random_state=2222,shuffle=False)
    train_final=[]
    for train_index, test_index in kf.split(train):
        train_fold, val_fold = train.loc[train_index], train.loc[test_index]
        for  feautres in categorical_feautres:
            agg=target_encoding(train_fold,feautres)
            val_fold=val_fold.merge(agg,how="left",on=feautres)
        train_final.append(val_fold)
    
    for  feautres in categorical_feautres : 
        agg=target_encoding(train,feautres)
        test=test.merge(agg,how="left",on=feautres)
        
        
    return pd.concat(train_final),test

# %%
train_KTE=train.copy()
test_KTE=test.copy()

# %%
train_KTE,test_KTE=add_target_encoding_features_Kfold(train=train_KTE,test=test_KTE)

# %%
test_KTE.head()
# Out:
#    ride_id travel_date travel_time travel_from car_type  max_capacity  \
# 0      247  2018-05-07       07:06       Kisii      Bus            49
# 1      256  2018-05-06       11:08       Kisii  shuttle            11
# 2      275  2018-05-04       05:00       Kisii  shuttle            11
# 3      285  2018-05-04       09:10       Kisii  shuttle            11
# 4      286  2018-05-04       09:20       Kisii  shuttle            11
#
#                  date  dayofweek  hour  minute  \
# 0 2018-05-07 07:06:00          0     7       6
# 1 2018-05-06 11:08:00          6    11       8
# 2 2018-05-04 05:00:00          4     5       0
# 3 2018-05-04 09:10:00          4     9      10
# 4 2018-05-04 09:20:00          4     9      20
#
#                 ...                std_per_dayofweek_number_of_ticket  \
# 0               ...                                          8.991864
# 1               ...                                          8.599534
# 2               ...                                          8.407693
# 3               ...                                          8.407693
# 4               ...                                          8.407693
#
#    mean_per_dayofweek_number_of_ticket  std_per_dayofmonth_number_of_ticket  \
# 0                             8.409198                             8.671242
# 1                             8.462121                             8.648121
# 2                             8.675573                             8.684263
# 3                             8.675573                             8.684263
# 4                             8.675573                             8.684263
#
#   mean_per_dayofmonth_number_of_ticket  std_per_hour_number_of_ticket  \
# 0                             8.464567                       9.739081
# 1                             8.680000                       3.799647
# 2                             8.115226                       3.478625
# 3                             8.115226                       3.662312
# 4                             8.115226                       3.662312
#
#    mean_per_hour_number_of_ticket  std_per_minute_number_of_ticket  \
# 0                        9.123711                         7.734458
# 1                        7.126437                         8.158904
# 2                        3.042169                         7.504519
# 3                        7.565574                         4.349472
# 4                        7.565574                         4.010635
#
#    mean_per_minute_number_of_ticket  std_per_year_number_of_ticket  \
# 0                          5.943925                       8.893375
# 1                          9.057229                       8.893375
# 2                          6.945166                       8.893375
# 3                          5.980583                       8.893375
# 4                          6.716981                       8.893375
#
#    mean_per_year_number_of_ticket
# 0                        8.229234
# 1                        8.229234
# 2                        8.229234
# 3                        8.229234
# 4                        8.229234
#
# [5 rows x 31 columns]

# %%
train_KTE.head()
# Out:
#    ride_id travel_date travel_time travel_from car_type  max_capacity  \
# 0     1442    17-10-17        7:15      Migori      Bus            49
# 1     5437    19-11-17        7:12      Migori      Bus            49
# 2     5710    26-11-17        7:05      Keroka      Bus            49
# 3     5777    27-11-17        7:10    Homa Bay      Bus            49
# 4     5778    27-11-17        7:12      Migori      Bus            49
#
#    number_of_ticket                date  dayofweek  dayofyear  \
# 0                 1 2017-10-17 07:15:00          1        290
# 1                 1 2017-11-19 07:12:00          6        323
# 2                 1 2017-11-26 07:05:00          6        330
# 3                 5 2017-11-27 07:10:00          0        331
# 4                31 2017-11-27 07:12:00          0        331
#
#                 ...                std_per_dayofweek_number_of_ticket  \
# 0               ...                                          8.886729
# 1               ...                                          8.826517
# 2               ...                                          8.826517
# 3               ...                                          9.153959
# 4               ...                                          9.153959
#
#   mean_per_dayofweek_number_of_ticket  std_per_dayofmonth_number_of_ticket  \
# 0                            8.912304                             9.062090
# 1                            8.768957                             9.072665
# 2                            8.768957                             9.079240
# 3                            8.797120                            10.705519
# 4                            8.797120                            10.705519
#
#    mean_per_dayofmonth_number_of_ticket  std_per_hour_number_of_ticket  \
# 0                              8.690722                       9.892324
# 1                              9.293839                       9.892324
# 2                              7.693694                       9.892324
# 3                              9.043750                       9.892324
# 4                              9.043750                       9.892324
#
#    mean_per_hour_number_of_ticket  std_per_minute_number_of_ticket  \
# 0                        9.381113                        10.962305
# 1                        9.381113                        14.532541
# 2                        9.381113                         5.885704
# 3                        9.381113                         4.382422
# 4                        9.381113                        14.532541
#
#    mean_per_minute_number_of_ticket  std_per_year_number_of_ticket  \
# 0                         13.103896                       7.908393
# 1                         23.198630                       7.908393
# 2                          6.936803                       7.908393
# 3                          6.070796                       7.908393
# 4                         23.198630                       7.908393
#
#    mean_per_year_number_of_ticket
# 0                        8.550272
# 1                        8.550272
# 2                        8.550272
# 3                        8.550272
# 4                        8.550272
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Training

# %% [markdown]
# Define a function to train the data in one fold which takes train, validation and test data and returns the prediction of the train, validation and test.

# %%
def train_model(X_train,Y_train,X_val,Y_val,X_test,parmaters,features_name): 
    d_train = xgb.DMatrix(X_train, Y_train,feature_names=features_name)
    d_valid = xgb.DMatrix(X_val, Y_val,feature_names=features_name)
    d_test = xgb.DMatrix(X_test,feature_names=features_name)
    list_track = [(d_train, 'train'), (d_valid, 'valid')]
    model = xgb.train(parmaters, d_train, 2000,  list_track, maximize=False, verbose_eval=50, early_stopping_rounds=50)
    train_pred =model.predict(d_train)              
    valid_pred =model.predict(d_valid)   
    test_pred = model.predict(d_test)
    return train_pred ,valid_pred,test_pred

# %% [markdown]
# Define K fold function which uses trian_model function with k fold and returns the prediction of the train for eachfold and the test set

# %%
def train_kfold(X_train,Y_train,X_test,parmaters,features_name,split=5,):
    final_train_pred=np.zeros_like(Y_train)
    final_test_pred=np.zeros(len(X_test))
    
    kf = KFold(n_splits=split,random_state=2222)
    i=1
    for train_index, val_index in kf.split(X_train):
        print("fold:"+str(i))
        train_fold_features, val_fold_features = X_train.loc[train_index], X_train.loc[val_index]
        train_fold_target, val_fold_target = Y_train.loc[train_index], Y_train.loc[val_index] 
        train_pred ,valid_pred,test_pred=train_model( 
                                                        X_train=train_fold_features,
                                                        Y_train= train_fold_target,
                                                        X_val= val_fold_features,
                                                        Y_val= val_fold_target,
                                                        X_test= X_test,
                                                        parmaters=parmaters,
                                                        features_name=features_name 
                                                    )
        
        final_train_pred[val_index]=valid_pred
        final_test_pred=final_test_pred+test_pred/split
        i=i+1
    return final_train_pred,final_train_pred

# %%
train.columns
# Out:
# Index(['ride_id', 'travel_date', 'travel_time', 'travel_from', 'car_type',
#        'max_capacity', 'number_of_ticket', 'date', 'dayofweek', 'dayofyear',
#        'dayofmonth', 'year_woy', 'hour', 'minute', 'is_weekend', 'year',
#        'quarter', 'month'],
#       dtype='object')

# %% [markdown]
# Remove useless columns.

# %%
columns_to_remove=['ride_id', 'travel_date', 'travel_time', 'travel_from', 'car_type',
       'max_capacity', 'number_of_ticket', 'date', 'dayofweek', 'dayofyear',
       'dayofmonth', 'year_woy', 'hour', 'minute', 'year',
       'quarter', 'month']
features_name=train_KTE.drop(columns_to_remove,axis=1).columns

# %% [markdown]
# ### Train the model with the first target encoding apporach

# %%
train_TE_train,train_TE_val=train_test_split(train_TE,random_state=1994,test_size=0.1)

X_train=train_TE_train[features_name]
Y_train=train_TE_train["number_of_ticket"]

X_val=train_TE_val[features_name]
Y_val=train_TE_val["number_of_ticket"]

X_test=test_TE[features_name]

# %%
params = {'eta': 0.004, 'colsample_bytree': 0.7, 
               'max_depth': 9,'subsample': 0.9, 'lambda': 4, 'nthread': 8, 'booster' : 'gbtree', 'silent': 1,
               'eval_metric': 'rmse', 'objective': 'reg:linear',"gamma":0.1 ,"alpha":0.01} 
train_pred ,valid_pred,test_pred=train_model(X_train,Y_train,X_val,Y_val,X_test,params,features_name)
# Out:
# [0]	train-rmse:11.5704	valid-rmse:11.6523
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 50 rounds.
# [50]	train-rmse:10.0544	valid-rmse:10.1954
# [100]	train-rmse:8.85509	valid-rmse:9.06086
# [150]	train-rmse:7.90693	valid-rmse:8.18352
# [200]	train-rmse:7.16422	valid-rmse:7.5106
# [250]	train-rmse:6.57704	valid-rmse:6.99349
# [300]	train-rmse:6.12004	valid-rmse:6.60618
# [350]	train-rmse:5.75626	valid-rmse:6.31382
# [400]	train-rmse:5.47005	valid-rmse:6.0987
# [450]	train-rmse:5.24	valid-rmse:5.9389
# [500]	train-rmse:5.04931	valid-rmse:5.81598
# [550]	train-rmse:4.89532	valid-rmse:5.72955
# [600]	train-rmse:4.7627	valid-rmse:5.66193
# [650]	train-rmse:4.64749	valid-rmse:5.61553
# [700]	train-rmse:4.5475	valid-rmse:5.58261
# [750]	train-rmse:4.45635	valid-rmse:5.55732
# [800]	train-rmse:4.37751	valid-rmse:5.53989
# [850]	train-rmse:4.30183	valid-rmse:5.52293
# [900]	train-rmse:4.23239	valid-rmse:5.51549
# [950]	train-rmse:4.16738	valid-rmse:5.5113
# [1000]	train-rmse:4.10641	valid-rmse:5.50813
# [1050]	train-rmse:4.0466	valid-rmse:5.50726
# [1100]	train-rmse:3.99443	valid-rmse:5.50706
# Stopping. Best iteration:
# [1071]	train-rmse:4.02387	valid-rmse:5.50434

# %%
print(mean_absolute_error.__name__,"Train",mean_absolute_error(train_pred,Y_train))
print(mean_absolute_error.__name__,"Validation",mean_absolute_error(Y_val,valid_pred))
# Out:
# mean_absolute_error Train 2.6593059340271976
# mean_absolute_error Validation 3.5368973982334135

# %% [markdown]
# ### Train the model with the second target encoding approach

# %%
X_train=train_VTE[features_name]
Y_train=train_VTE["number_of_ticket"]
X_val=val_VTE[features_name]
Y_val=val_VTE["number_of_ticket"]
X_test=test_VTE[features_name]

# %%
params = {'eta': 0.004, 'colsample_bytree': 0.7, 
               'max_depth': 9,'subsample': 0.9, 'lambda': 4, 'nthread': 8, 'booster' : 'gbtree', 'silent': 1,
               'eval_metric': 'rmse', 'objective': 'reg:linear',"gamma":0.1 ,"alpha":0.01} 
train_pred ,valid_pred,test_pred=train_model(X_train,Y_train,X_val,Y_val,X_test,params,features_name)
# Out:
# [0]	train-rmse:11.5704	valid-rmse:11.6517
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 50 rounds.
# [50]	train-rmse:10.0583	valid-rmse:10.2159
# [100]	train-rmse:8.86258	valid-rmse:9.10201
# [150]	train-rmse:7.91884	valid-rmse:8.24528
# [200]	train-rmse:7.18025	valid-rmse:7.58669
# [250]	train-rmse:6.5958	valid-rmse:7.08154
# [300]	train-rmse:6.14116	valid-rmse:6.70157
# [350]	train-rmse:5.78246	valid-rmse:6.41656
# [400]	train-rmse:5.49947	valid-rmse:6.20539
# [450]	train-rmse:5.27177	valid-rmse:6.04832
# [500]	train-rmse:5.08281	valid-rmse:5.92895
# [550]	train-rmse:4.93139	valid-rmse:5.84564
# [600]	train-rmse:4.7997	valid-rmse:5.78398
# [650]	train-rmse:4.68427	valid-rmse:5.73775
# [700]	train-rmse:4.58379	valid-rmse:5.70784
# [750]	train-rmse:4.49348	valid-rmse:5.68334
# [800]	train-rmse:4.41434	valid-rmse:5.66467
# [850]	train-rmse:4.33914	valid-rmse:5.65378
# [900]	train-rmse:4.27125	valid-rmse:5.64794
# [950]	train-rmse:4.20651	valid-rmse:5.6426
# [1000]	train-rmse:4.14837	valid-rmse:5.6391
# [1050]	train-rmse:4.0908	valid-rmse:5.63539
# Stopping. Best iteration:
# [1046]	train-rmse:4.09561	valid-rmse:5.63426

# %%
print(mean_absolute_error.__name__,"Train",mean_absolute_error(train_pred,Y_train))
print(mean_absolute_error.__name__,"Validation",mean_absolute_error(Y_val,valid_pred))
# Out:
# mean_absolute_error Train 2.6953015041194464
# mean_absolute_error Validation 3.5934159786224367

# %% [markdown]
# ### Train the model with the first target encoding approach with k fold

# %%
X_train=train_TE[features_name]
Y_train=train_TE["number_of_ticket"]
X_test=test_TE[features_name]

# %%
train_pred,test_pred= train_kfold(X_train,Y_train,X_test,params,features_name,split=10)
# Out:
# fold:1
# [0]	train-rmse:11.9764	valid-rmse:7.04547
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 50 rounds.
# [50]	train-rmse:10.3868	valid-rmse:6.05281
# [100]	train-rmse:9.12596	valid-rmse:5.39235
# [150]	train-rmse:8.12612	valid-rmse:4.99034
# [200]	train-rmse:7.34182	valid-rmse:4.78126
# [250]	train-rmse:6.71994	valid-rmse:4.69667
# [300]	train-rmse:6.23433	valid-rmse:4.69244
# Stopping. Best iteration:
# [276]	train-rmse:6.45371	valid-rmse:4.68513
#
# fold:2
# [0]	train-rmse:11.6743	valid-rmse:10.6828
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 50 rounds.
# [50]	train-rmse:10.153	valid-rmse:9.35479
# [100]	train-rmse:8.94872	valid-rmse:8.31074
# [150]	train-rmse:7.99657	valid-rmse:7.48187
# [200]	train-rmse:7.25053	valid-rmse:6.83232
# [250]	train-rmse:6.65869	valid-rmse:6.3354
# [300]	train-rmse:6.19655	valid-rmse:5.96539
# [350]	train-rmse:5.82563	valid-rmse:5.67467
# [400]	train-rmse:5.53645	valid-rmse:5.45751
# [450]	train-rmse:5.30309	valid-rmse:5.29455
# [500]	train-rmse:5.10849	valid-rmse:5.17115
# [550]	train-rmse:4.95158	valid-rmse:5.08294
# [600]	train-rmse:4.81971	valid-rmse:5.01007
# [650]	train-rmse:4.7023	valid-rmse:4.95801
# [700]	train-rmse:4.59966	valid-rmse:4.91787
# [750]	train-rmse:4.50522	valid-rmse:4.88811
# [800]	train-rmse:4.42312	valid-rmse:4.86617
# [850]	train-rmse:4.34651	valid-rmse:4.84885
# [900]	train-rmse:4.27708	valid-rmse:4.84171
# [950]	train-rmse:4.21023	valid-rmse:4.82935
# [1000]	train-rmse:4.15028	valid-rmse:4.8235
# [1050]	train-rmse:4.09289	valid-rmse:4.82339
# [1100]	train-rmse:4.04074	valid-rmse:4.82187
# [1150]	train-rmse:3.99257	valid-rmse:4.82511
# Stopping. Best iteration:
# [1106]	train-rmse:4.03514	valid-rmse:4.82159
#
# fold:3
# [0]	train-rmse:11.5867	valid-rmse:11.5113
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 50 rounds.
# [50]	train-rmse:10.0638	valid-rmse:10.231
# [100]	train-rmse:8.85662	valid-rmse:9.2731
# [150]	train-rmse:7.90001	valid-rmse:8.5708
# [200]	train-rmse:7.15354	valid-rmse:8.05149
# [250]	train-rmse:6.56616	valid-rmse:7.67042
# [300]	train-rmse:6.10806	valid-rmse:7.41363
# [350]	train-rmse:5.74459	valid-rmse:7.2162
# [400]	train-rmse:5.46145	valid-rmse:7.07992
# [450]	train-rmse:5.23485	valid-rmse:6.9831
# [500]	train-rmse:5.04579	valid-rmse:6.904
# [550]	train-rmse:4.89285	valid-rmse:6.84807
# [600]	train-rmse:4.76481	valid-rmse:6.81437
# [650]	train-rmse:4.651	valid-rmse:6.7828
# [700]	train-rmse:4.55026	valid-rmse:6.75971
# [750]	train-rmse:4.46143	valid-rmse:6.7448
# [800]	train-rmse:4.38284	valid-rmse:6.73522
# [850]	train-rmse:4.30837	valid-rmse:6.73049
# [900]	train-rmse:4.24069	valid-rmse:6.7296
# Stopping. Best iteration:
# [880]	train-rmse:4.26803	valid-rmse:6.7279
#
# fold:4
# [0]	train-rmse:11.4949	valid-rmse:12.3119
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 50 rounds.
# [50]	train-rmse:9.96913	valid-rmse:11.0942
# [100]	train-rmse:8.75726	valid-rmse:10.19
# [150]	train-rmse:7.79325	valid-rmse:9.52763
# [200]	train-rmse:7.03428	valid-rmse:9.0428
# [250]	train-rmse:6.43194	valid-rmse:8.6822
# [300]	train-rmse:5.9611	valid-rmse:8.43918
# [350]	train-rmse:5.58719	valid-rmse:8.25507
# [400]	train-rmse:5.29486	valid-rmse:8.11756
# [450]	train-rmse:5.05764	valid-rmse:8.01394
# [500]	train-rmse:4.86454	valid-rmse:7.93529
# [550]	train-rmse:4.71002	valid-rmse:7.87414
# [600]	train-rmse:4.57906	valid-rmse:7.82848
# [650]	train-rmse:4.46283	valid-rmse:7.792
# [700]	train-rmse:4.36491	valid-rmse:7.7642
# [750]	train-rmse:4.27783	valid-rmse:7.74388
# [800]	train-rmse:4.20152	valid-rmse:7.72633
# [850]	train-rmse:4.13168	valid-rmse:7.7155
# [900]	train-rmse:4.06804	valid-rmse:7.70524
# [950]	train-rmse:4.00855	valid-rmse:7.69746
# [1000]	train-rmse:3.95419	valid-rmse:7.69279
# [1050]	train-rmse:3.90348	valid-rmse:7.68764
# [1100]	train-rmse:3.85513	valid-rmse:7.68581
# [1150]	train-rmse:3.81242	valid-rmse:7.68024
# [1200]	train-rmse:3.76945	valid-rmse:7.67876
# [1250]	train-rmse:3.73058	valid-rmse:7.67483
# [1300]	train-rmse:3.69232	valid-rmse:7.6742
# [1350]	train-rmse:3.65576	valid-rmse:7.67335
# [1400]	train-rmse:3.62178	valid-rmse:7.6726
# [1450]	train-rmse:3.59018	valid-rmse:7.67007
# [1500]	train-rmse:3.55886	valid-rmse:7.6682
# [1550]	train-rmse:3.53098	valid-rmse:7.66558
# [1600]	train-rmse:3.50192	valid-rmse:7.66667
# Stopping. Best iteration:
# [1581]	train-rmse:3.51245	valid-rmse:7.66506
#
# fold:5
# [0]	train-rmse:11.7169	valid-rmse:10.2515
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 50 rounds.
# [50]	train-rmse:10.1862	valid-rmse:8.82299
# [100]	train-rmse:8.9744	valid-rmse:7.71438
# [150]	train-rmse:8.01526	valid-rmse:6.8702
# [200]	train-rmse:7.26138	valid-rmse:6.23806
# [250]	train-rmse:6.66466	valid-rmse:5.76445
# [300]	train-rmse:6.19577	valid-rmse:5.4299
# [350]	train-rmse:5.82454	valid-rmse:5.19224
# [400]	train-rmse:5.53347	valid-rmse:5.0283
# [450]	train-rmse:5.29722	valid-rmse:4.92069
# [500]	train-rmse:5.10184	valid-rmse:4.84819
# [550]	train-rmse:4.94221	valid-rmse:4.80549
# [600]	train-rmse:4.80642	valid-rmse:4.78246
# [650]	train-rmse:4.68659	valid-rmse:4.77286
# [700]	train-rmse:4.5809	valid-rmse:4.76996
# [750]	train-rmse:4.48631	valid-rmse:4.7721
# Stopping. Best iteration:
# [713]	train-rmse:4.55786	valid-rmse:4.76947
#
# fold:6
# [0]	train-rmse:11.6521	valid-rmse:10.8946
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 50 rounds.
# [50]	train-rmse:10.1323	valid-rmse:9.31894
# [100]	train-rmse:8.9269	valid-rmse:8.08792
# [150]	train-rmse:7.97036	valid-rmse:7.13854
# [200]	train-rmse:7.21923	valid-rmse:6.43483
# [250]	train-rmse:6.62209	valid-rmse:5.92579
# [300]	train-rmse:6.15302	valid-rmse:5.58127
# [350]	train-rmse:5.77846	valid-rmse:5.3611
# [400]	train-rmse:5.4846	valid-rmse:5.23224
# [450]	train-rmse:5.24888	valid-rmse:5.16165
# [500]	train-rmse:5.05256	valid-rmse:5.12577
# [550]	train-rmse:4.89501	valid-rmse:5.12331
# Stopping. Best iteration:
# [533]	train-rmse:4.94546	valid-rmse:5.11982
#
# fold:7
# [0]	train-rmse:11.4938	valid-rmse:12.3184
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 50 rounds.
# [50]	train-rmse:9.99176	valid-rmse:10.7977
# [100]	train-rmse:8.80429	valid-rmse:9.6198
# [150]	train-rmse:7.86364	valid-rmse:8.70071
# [200]	train-rmse:7.12453	valid-rmse:7.99459
# [250]	train-rmse:6.53655	valid-rmse:7.46694
# [300]	train-rmse:6.07727	valid-rmse:7.08286
# [350]	train-rmse:5.70952	valid-rmse:6.7889
# [400]	train-rmse:5.42001	valid-rmse:6.57645
# [450]	train-rmse:5.18671	valid-rmse:6.4195
# [500]	train-rmse:4.99301	valid-rmse:6.30724
# [550]	train-rmse:4.83695	valid-rmse:6.22789
# [600]	train-rmse:4.69987	valid-rmse:6.18156
# [650]	train-rmse:4.58114	valid-rmse:6.14839
# [700]	train-rmse:4.47613	valid-rmse:6.12983
# [750]	train-rmse:4.37934	valid-rmse:6.11233
# [800]	train-rmse:4.29748	valid-rmse:6.10904
# [850]	train-rmse:4.22113	valid-rmse:6.1101
# Stopping. Best iteration:
# [808]	train-rmse:4.28442	valid-rmse:6.10839
#
# fold:8
# [0]	train-rmse:11.43	valid-rmse:12.8445
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 50 rounds.
# [50]	train-rmse:9.94168	valid-rmse:11.2995
# [100]	train-rmse:8.7644	valid-rmse:10.0638
# [150]	train-rmse:7.83341	valid-rmse:9.07937
# [200]	train-rmse:7.10247	valid-rmse:8.30116
# [250]	train-rmse:6.52234	valid-rmse:7.69214
# [300]	train-rmse:6.07112	valid-rmse:7.23475
# [350]	train-rmse:5.71114	valid-rmse:6.88071
# [400]	train-rmse:5.42863	valid-rmse:6.61775
# [450]	train-rmse:5.19915	valid-rmse:6.41766
# [500]	train-rmse:5.00889	valid-rmse:6.25702
# [550]	train-rmse:4.85361	valid-rmse:6.14315
# [600]	train-rmse:4.71932	valid-rmse:6.05244
# [650]	train-rmse:4.60313	valid-rmse:5.98218
# [700]	train-rmse:4.49904	valid-rmse:5.92685
# [750]	train-rmse:4.40279	valid-rmse:5.88018
# [800]	train-rmse:4.32018	valid-rmse:5.8416
# [850]	train-rmse:4.24365	valid-rmse:5.81464
# [900]	train-rmse:4.17474	valid-rmse:5.79575
# [950]	train-rmse:4.107	valid-rmse:5.78359
# [1000]	train-rmse:4.04599	valid-rmse:5.76864
# [1050]	train-rmse:3.98929	valid-rmse:5.75962
# [1100]	train-rmse:3.93487	valid-rmse:5.75037
# [1150]	train-rmse:3.8877	valid-rmse:5.74455
# [1200]	train-rmse:3.8403	valid-rmse:5.74051
# [1250]	train-rmse:3.79871	valid-rmse:5.73733
# [1300]	train-rmse:3.75604	valid-rmse:5.73818
# Stopping. Best iteration:
# [1266]	train-rmse:3.78472	valid-rmse:5.73642
#
# fold:9
# [0]	train-rmse:11.4491	valid-rmse:12.6909
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 50 rounds.
# [50]	train-rmse:9.96074	valid-rmse:11.1513
# [100]	train-rmse:8.78076	valid-rmse:9.93171
# [150]	train-rmse:7.84716	valid-rmse:8.99781
# [200]	train-rmse:7.11337	valid-rmse:8.27367
# [250]	train-rmse:6.53031	valid-rmse:7.72264
# [300]	train-rmse:6.07608	valid-rmse:7.32185
# [350]	train-rmse:5.71254	valid-rmse:7.00523
# [400]	train-rmse:5.42721	valid-rmse:6.76924
# [450]	train-rmse:5.19657	valid-rmse:6.59878
# [500]	train-rmse:5.00683	valid-rmse:6.46708
# [550]	train-rmse:4.85104	valid-rmse:6.37092
# [600]	train-rmse:4.7135	valid-rmse:6.30138
# [650]	train-rmse:4.59472	valid-rmse:6.24885
# [700]	train-rmse:4.48947	valid-rmse:6.20592
# [750]	train-rmse:4.39577	valid-rmse:6.1789
# [800]	train-rmse:4.31434	valid-rmse:6.15879
# [850]	train-rmse:4.23765	valid-rmse:6.14605
# [900]	train-rmse:4.16643	valid-rmse:6.14126
# [950]	train-rmse:4.09992	valid-rmse:6.13979
# [1000]	train-rmse:4.03842	valid-rmse:6.13936
# Stopping. Best iteration:
# [982]	train-rmse:4.06074	valid-rmse:6.13702
#
# fold:10
# [0]	train-rmse:11.297	valid-rmse:13.8493
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 50 rounds.
# [50]	train-rmse:9.83076	valid-rmse:12.2194
# [100]	train-rmse:8.68418	valid-rmse:10.9361
# [150]	train-rmse:7.77175	valid-rmse:9.91902
# [200]	train-rmse:7.06412	valid-rmse:9.15262
# [250]	train-rmse:6.50791	valid-rmse:8.55743
# [300]	train-rmse:6.0694	valid-rmse:8.10278
# [350]	train-rmse:5.72121	valid-rmse:7.75134
# [400]	train-rmse:5.44778	valid-rmse:7.48651
# [450]	train-rmse:5.22219	valid-rmse:7.29545
# [500]	train-rmse:5.03835	valid-rmse:7.1523
# [550]	train-rmse:4.88019	valid-rmse:7.04855
# [600]	train-rmse:4.74606	valid-rmse:6.9652
# [650]	train-rmse:4.6287	valid-rmse:6.91349
# [700]	train-rmse:4.52641	valid-rmse:6.87273
# [750]	train-rmse:4.43725	valid-rmse:6.83562
# [800]	train-rmse:4.35652	valid-rmse:6.81952
# [850]	train-rmse:4.28256	valid-rmse:6.80641
# [900]	train-rmse:4.21455	valid-rmse:6.7942
# [950]	train-rmse:4.15496	valid-rmse:6.7886
# [1000]	train-rmse:4.09831	valid-rmse:6.78352
# [1050]	train-rmse:4.0443	valid-rmse:6.78539
# Stopping. Best iteration:
# [1013]	train-rmse:4.08461	valid-rmse:6.78233

# %%
print(mean_absolute_error.__name__,"CV =",mean_absolute_error(train_pred,Y_train))
# Out:
# mean_absolute_error CV = 3.8751800288046088

# %% [markdown]
# ### Train the model with the third target encoding approach

# %%
train_KTE.reset_index(inplace=True,drop=True)
X_train=train_KTE[features_name]
Y_train=train_KTE["number_of_ticket"]
X_test=test_KTE[features_name]

# %%
train_pred,test_pred= train_kfold(X_train,Y_train,X_test,params,features_name,split=10)
# Out:
# fold:1
# [0]	train-rmse:11.9762	valid-rmse:7.04534
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 50 rounds.
# [50]	train-rmse:10.3453	valid-rmse:6.21458
# [100]	train-rmse:9.03558	valid-rmse:5.64969
# [150]	train-rmse:7.98153	valid-rmse:5.28501
# [200]	train-rmse:7.14185	valid-rmse:5.05656
# [250]	train-rmse:6.46619	valid-rmse:4.92753
# [300]	train-rmse:5.93194	valid-rmse:4.86801
# [350]	train-rmse:5.4928	valid-rmse:4.84657
# [400]	train-rmse:5.14474	valid-rmse:4.857
# Stopping. Best iteration:
# [352]	train-rmse:5.47863	valid-rmse:4.84657
#
# fold:2
# [0]	train-rmse:11.6739	valid-rmse:10.6839
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 50 rounds.
# [50]	train-rmse:10.1079	valid-rmse:9.48016
# [100]	train-rmse:8.85012	valid-rmse:8.47487
# [150]	train-rmse:7.83657	valid-rmse:7.71521
# [200]	train-rmse:7.02906	valid-rmse:7.11543
# [250]	train-rmse:6.37873	valid-rmse:6.63447
# [300]	train-rmse:5.86441	valid-rmse:6.27365
# [350]	train-rmse:5.44057	valid-rmse:5.99174
# [400]	train-rmse:5.10388	valid-rmse:5.78098
# [450]	train-rmse:4.82564	valid-rmse:5.61887
# [500]	train-rmse:4.59301	valid-rmse:5.48657
# [550]	train-rmse:4.40105	valid-rmse:5.38819
# [600]	train-rmse:4.23653	valid-rmse:5.31637
# [650]	train-rmse:4.09573	valid-rmse:5.25443
# [700]	train-rmse:3.96895	valid-rmse:5.20922
# [750]	train-rmse:3.85978	valid-rmse:5.16866
# [800]	train-rmse:3.76229	valid-rmse:5.13593
# [850]	train-rmse:3.67466	valid-rmse:5.11599
# [900]	train-rmse:3.59487	valid-rmse:5.09778
# [950]	train-rmse:3.51957	valid-rmse:5.08557
# [1000]	train-rmse:3.45379	valid-rmse:5.06968
# [1050]	train-rmse:3.3947	valid-rmse:5.06349
# [1100]	train-rmse:3.33898	valid-rmse:5.05556
# [1150]	train-rmse:3.28797	valid-rmse:5.05015
# [1200]	train-rmse:3.23915	valid-rmse:5.04487
# [1250]	train-rmse:3.19352	valid-rmse:5.03857
# [1300]	train-rmse:3.1497	valid-rmse:5.03677
# [1350]	train-rmse:3.10922	valid-rmse:5.03199
# [1400]	train-rmse:3.06815	valid-rmse:5.02827
# [1450]	train-rmse:3.03251	valid-rmse:5.02631
# [1500]	train-rmse:2.99577	valid-rmse:5.0256
# Stopping. Best iteration:
# [1470]	train-rmse:3.01781	valid-rmse:5.02428
#
# fold:3
# [0]	train-rmse:11.5863	valid-rmse:11.5053
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 50 rounds.
# [50]	train-rmse:10.0208	valid-rmse:10.1585
# [100]	train-rmse:8.76789	valid-rmse:9.14175
# [150]	train-rmse:7.76006	valid-rmse:8.39632
# [200]	train-rmse:6.95564	valid-rmse:7.86845
# [250]	train-rmse:6.31081	valid-rmse:7.47584
# [300]	train-rmse:5.8005	valid-rmse:7.19609
# [350]	train-rmse:5.3853	valid-rmse:6.98899
# [400]	train-rmse:5.05666	valid-rmse:6.85105
# [450]	train-rmse:4.78736	valid-rmse:6.74743
# [500]	train-rmse:4.56198	valid-rmse:6.66538
# [550]	train-rmse:4.38105	valid-rmse:6.60782
# [600]	train-rmse:4.22736	valid-rmse:6.56345
# [650]	train-rmse:4.09376	valid-rmse:6.52837
# [700]	train-rmse:3.97519	valid-rmse:6.50526
# [750]	train-rmse:3.87098	valid-rmse:6.48643
# [800]	train-rmse:3.77617	valid-rmse:6.46571
# [850]	train-rmse:3.69076	valid-rmse:6.45525
# [900]	train-rmse:3.61414	valid-rmse:6.44366
# [950]	train-rmse:3.54207	valid-rmse:6.43467
# [1000]	train-rmse:3.47688	valid-rmse:6.42689
# [1050]	train-rmse:3.41932	valid-rmse:6.4224
# [1100]	train-rmse:3.36728	valid-rmse:6.41942
# [1150]	train-rmse:3.31669	valid-rmse:6.41836
# [1200]	train-rmse:3.2676	valid-rmse:6.41727
# [1250]	train-rmse:3.22278	valid-rmse:6.41494
# [1300]	train-rmse:3.18005	valid-rmse:6.4096
# [1350]	train-rmse:3.14058	valid-rmse:6.40721
# [1400]	train-rmse:3.10051	valid-rmse:6.40644
# [1450]	train-rmse:3.06157	valid-rmse:6.40488
# [1500]	train-rmse:3.02392	valid-rmse:6.40116
# [1550]	train-rmse:2.99249	valid-rmse:6.40216
# Stopping. Best iteration:
# [1518]	train-rmse:3.01259	valid-rmse:6.40081
#
# fold:4
# [0]	train-rmse:11.4948	valid-rmse:12.3119
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 50 rounds.
# [50]	train-rmse:9.93719	valid-rmse:11.1079
# [100]	train-rmse:8.69169	valid-rmse:10.1769
# [150]	train-rmse:7.69147	valid-rmse:9.46977
# [200]	train-rmse:6.89425	valid-rmse:8.94975
# [250]	train-rmse:6.25265	valid-rmse:8.54793
# [300]	train-rmse:5.74558	valid-rmse:8.26365
# [350]	train-rmse:5.33361	valid-rmse:8.0543
# [400]	train-rmse:5.00329	valid-rmse:7.89443
# [450]	train-rmse:4.73282	valid-rmse:7.78059
# [500]	train-rmse:4.50717	valid-rmse:7.68943
# [550]	train-rmse:4.32186	valid-rmse:7.62662
# [600]	train-rmse:4.16503	valid-rmse:7.5815
# [650]	train-rmse:4.03058	valid-rmse:7.55067
# [700]	train-rmse:3.90983	valid-rmse:7.52788
# [750]	train-rmse:3.80435	valid-rmse:7.51031
# [800]	train-rmse:3.7101	valid-rmse:7.49549
# [850]	train-rmse:3.62597	valid-rmse:7.48428
# [900]	train-rmse:3.54957	valid-rmse:7.47707
# [950]	train-rmse:3.47814	valid-rmse:7.46688
# [1000]	train-rmse:3.41235	valid-rmse:7.45959
# [1050]	train-rmse:3.35555	valid-rmse:7.45341
# [1100]	train-rmse:3.30029	valid-rmse:7.44813
# [1150]	train-rmse:3.25155	valid-rmse:7.44529
# [1200]	train-rmse:3.20326	valid-rmse:7.43994
# [1250]	train-rmse:3.15936	valid-rmse:7.43588
# [1300]	train-rmse:3.11495	valid-rmse:7.43012
# [1350]	train-rmse:3.07339	valid-rmse:7.42407
# [1400]	train-rmse:3.03537	valid-rmse:7.41735
# [1450]	train-rmse:3.00132	valid-rmse:7.41373
# [1500]	train-rmse:2.96665	valid-rmse:7.41082
# Stopping. Best iteration:
# [1488]	train-rmse:2.97478	valid-rmse:7.41027
#
# fold:5
# [0]	train-rmse:11.7164	valid-rmse:10.2597
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 50 rounds.
# [50]	train-rmse:10.1328	valid-rmse:9.37273
# [100]	train-rmse:8.86417	valid-rmse:8.72542
# [150]	train-rmse:7.84528	valid-rmse:8.13797
# [200]	train-rmse:7.03396	valid-rmse:7.71672
# [250]	train-rmse:6.38071	valid-rmse:7.3822
# [300]	train-rmse:5.86343	valid-rmse:7.13454
# [350]	train-rmse:5.44127	valid-rmse:6.97985
# [400]	train-rmse:5.10592	valid-rmse:6.83961
# [450]	train-rmse:4.82973	valid-rmse:6.73703
# [500]	train-rmse:4.59725	valid-rmse:6.66159
# [550]	train-rmse:4.40956	valid-rmse:6.6012
# [600]	train-rmse:4.24991	valid-rmse:6.53666
# [650]	train-rmse:4.11147	valid-rmse:6.49915
# [700]	train-rmse:3.98869	valid-rmse:6.46713
# [750]	train-rmse:3.87975	valid-rmse:6.43323
# [800]	train-rmse:3.78425	valid-rmse:6.40534
# [850]	train-rmse:3.6975	valid-rmse:6.39192
# [900]	train-rmse:3.62003	valid-rmse:6.37618
# [950]	train-rmse:3.54611	valid-rmse:6.3603
# [1000]	train-rmse:3.4802	valid-rmse:6.34905
# [1050]	train-rmse:3.42077	valid-rmse:6.33838
# Stopping. Best iteration:
# [1047]	train-rmse:3.42349	valid-rmse:6.3364
#
# fold:6
# [0]	train-rmse:11.6518	valid-rmse:10.9015
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 50 rounds.
# [50]	train-rmse:10.0857	valid-rmse:9.51345
# [100]	train-rmse:8.82863	valid-rmse:8.40826
# [150]	train-rmse:7.81545	valid-rmse:7.52603
# [200]	train-rmse:7.01042	valid-rmse:6.85754
# [250]	train-rmse:6.36045	valid-rmse:6.34818
# [300]	train-rmse:5.84541	valid-rmse:5.98115
# [350]	train-rmse:5.42735	valid-rmse:5.70009
# [400]	train-rmse:5.09241	valid-rmse:5.49318
# [450]	train-rmse:4.81845	valid-rmse:5.34043
# [500]	train-rmse:4.58941	valid-rmse:5.22248
# [550]	train-rmse:4.40296	valid-rmse:5.14449
# [600]	train-rmse:4.24485	valid-rmse:5.08896
# [650]	train-rmse:4.10705	valid-rmse:5.0396
# [700]	train-rmse:3.98549	valid-rmse:5.00628
# [750]	train-rmse:3.87744	valid-rmse:4.98803
# [800]	train-rmse:3.78224	valid-rmse:4.97275
# [850]	train-rmse:3.69721	valid-rmse:4.9603
# [900]	train-rmse:3.62031	valid-rmse:4.95533
# [950]	train-rmse:3.5451	valid-rmse:4.95058
# [1000]	train-rmse:3.4796	valid-rmse:4.94953
# [1050]	train-rmse:3.42004	valid-rmse:4.94952
# [1100]	train-rmse:3.36259	valid-rmse:4.94729
# Stopping. Best iteration:
# [1093]	train-rmse:3.37008	valid-rmse:4.94674
#
# fold:7
# [0]	train-rmse:11.4934	valid-rmse:12.3164
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 50 rounds.
# [50]	train-rmse:9.9458	valid-rmse:10.8396
# [100]	train-rmse:8.70468	valid-rmse:9.67652
# [150]	train-rmse:7.70869	valid-rmse:8.77768
# [200]	train-rmse:6.91156	valid-rmse:8.08611
# [250]	train-rmse:6.26839	valid-rmse:7.56448
# [300]	train-rmse:5.75828	valid-rmse:7.17611
# [350]	train-rmse:5.34282	valid-rmse:6.87985
# [400]	train-rmse:5.01103	valid-rmse:6.66522
# [450]	train-rmse:4.73712	valid-rmse:6.5007
# [500]	train-rmse:4.50987	valid-rmse:6.37455
# [550]	train-rmse:4.32295	valid-rmse:6.27957
# [600]	train-rmse:4.16431	valid-rmse:6.20213
# [650]	train-rmse:4.02534	valid-rmse:6.15205
# [700]	train-rmse:3.90281	valid-rmse:6.11141
# [750]	train-rmse:3.79398	valid-rmse:6.08559
# [800]	train-rmse:3.69629	valid-rmse:6.06089
# [850]	train-rmse:3.61092	valid-rmse:6.0447
# [900]	train-rmse:3.53329	valid-rmse:6.03249
# [950]	train-rmse:3.46101	valid-rmse:6.01917
# [1000]	train-rmse:3.3957	valid-rmse:6.01399
# [1050]	train-rmse:3.33541	valid-rmse:6.01227
# [1100]	train-rmse:3.27881	valid-rmse:6.00802
# [1150]	train-rmse:3.22692	valid-rmse:6.00803
# Stopping. Best iteration:
# [1142]	train-rmse:3.2345	valid-rmse:6.00727
#
# fold:8
# [0]	train-rmse:11.4295	valid-rmse:12.8456
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 50 rounds.
# [50]	train-rmse:9.89154	valid-rmse:11.3511
# [100]	train-rmse:8.65668	valid-rmse:10.1806
# [150]	train-rmse:7.66409	valid-rmse:9.26717
# [200]	train-rmse:6.874	valid-rmse:8.53333
# [250]	train-rmse:6.23677	valid-rmse:7.95959
# [300]	train-rmse:5.73171	valid-rmse:7.5363
# [350]	train-rmse:5.31994	valid-rmse:7.19625
# [400]	train-rmse:4.99154	valid-rmse:6.94282
# [450]	train-rmse:4.72072	valid-rmse:6.74595
# [500]	train-rmse:4.49508	valid-rmse:6.60088
# [550]	train-rmse:4.30899	valid-rmse:6.47926
# [600]	train-rmse:4.15033	valid-rmse:6.38571
# [650]	train-rmse:4.01274	valid-rmse:6.31939
# [700]	train-rmse:3.89053	valid-rmse:6.26711
# [750]	train-rmse:3.7832	valid-rmse:6.2287
# [800]	train-rmse:3.68731	valid-rmse:6.19688
# [850]	train-rmse:3.60383	valid-rmse:6.17318
# [900]	train-rmse:3.52751	valid-rmse:6.15932
# [950]	train-rmse:3.45556	valid-rmse:6.15132
# [1000]	train-rmse:3.39017	valid-rmse:6.14407
# [1050]	train-rmse:3.33162	valid-rmse:6.13844
# [1100]	train-rmse:3.27618	valid-rmse:6.13374
# [1150]	train-rmse:3.22575	valid-rmse:6.12892
# [1200]	train-rmse:3.17756	valid-rmse:6.1231
# [1250]	train-rmse:3.13085	valid-rmse:6.12339
# [1300]	train-rmse:3.08648	valid-rmse:6.12136
# [1350]	train-rmse:3.04402	valid-rmse:6.11843
# [1400]	train-rmse:3.00689	valid-rmse:6.11807
# [1450]	train-rmse:2.96865	valid-rmse:6.11861
# Stopping. Best iteration:
# [1434]	train-rmse:2.98112	valid-rmse:6.11758
#
# fold:9
# [0]	train-rmse:11.4486	valid-rmse:12.6955
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 50 rounds.
# [50]	train-rmse:9.91152	valid-rmse:11.1165
# [100]	train-rmse:8.67926	valid-rmse:9.89483
# [150]	train-rmse:7.68902	valid-rmse:9.01528
# [200]	train-rmse:6.90049	valid-rmse:8.34581
# [250]	train-rmse:6.26573	valid-rmse:7.80701
# [300]	train-rmse:5.76307	valid-rmse:7.42654
# [350]	train-rmse:5.3541	valid-rmse:7.11342
# [400]	train-rmse:5.02745	valid-rmse:6.86199
# [450]	train-rmse:4.76064	valid-rmse:6.67546
# [500]	train-rmse:4.53793	valid-rmse:6.52743
# [550]	train-rmse:4.35499	valid-rmse:6.40581
# [600]	train-rmse:4.19858	valid-rmse:6.31573
# [650]	train-rmse:4.0636	valid-rmse:6.23288
# [700]	train-rmse:3.94184	valid-rmse:6.17185
# [750]	train-rmse:3.83857	valid-rmse:6.12487
# [800]	train-rmse:3.74488	valid-rmse:6.08057
# [850]	train-rmse:3.66131	valid-rmse:6.04797
# [900]	train-rmse:3.58523	valid-rmse:6.01664
# [950]	train-rmse:3.51326	valid-rmse:5.99399
# [1000]	train-rmse:3.4489	valid-rmse:5.97495
# [1050]	train-rmse:3.38833	valid-rmse:5.96178
# [1100]	train-rmse:3.33299	valid-rmse:5.94979
# [1150]	train-rmse:3.28432	valid-rmse:5.93958
# [1200]	train-rmse:3.23592	valid-rmse:5.92721
# [1250]	train-rmse:3.192	valid-rmse:5.91756
# [1300]	train-rmse:3.15067	valid-rmse:5.9127
# [1350]	train-rmse:3.11071	valid-rmse:5.90927
# [1400]	train-rmse:3.07334	valid-rmse:5.90453
# [1450]	train-rmse:3.03791	valid-rmse:5.90136
# [1500]	train-rmse:3.00255	valid-rmse:5.89841
# [1550]	train-rmse:2.96993	valid-rmse:5.89686
# [1600]	train-rmse:2.93899	valid-rmse:5.89472
# [1650]	train-rmse:2.90648	valid-rmse:5.89246
# [1700]	train-rmse:2.87649	valid-rmse:5.89155
# [1750]	train-rmse:2.84906	valid-rmse:5.8914
# Stopping. Best iteration:
# [1715]	train-rmse:2.86852	valid-rmse:5.89013
#
# fold:10
# [0]	train-rmse:11.2959	valid-rmse:13.8513
# Multiple eval metrics have been passed: 'valid-rmse' will be used for early stopping.
#
# Will train until valid-rmse hasn't improved in 50 rounds.
# [50]	train-rmse:9.77914	valid-rmse:12.2988
# [100]	train-rmse:8.57553	valid-rmse:11.1073
# [150]	train-rmse:7.60087	valid-rmse:10.1788
# [200]	train-rmse:6.82885	valid-rmse:9.46912
# [250]	train-rmse:6.21786	valid-rmse:8.93022
# [300]	train-rmse:5.72878	valid-rmse:8.52124
# [350]	train-rmse:5.33659	valid-rmse:8.2026
# [400]	train-rmse:5.02087	valid-rmse:7.96287
# [450]	train-rmse:4.76038	valid-rmse:7.78547
# [500]	train-rmse:4.54674	valid-rmse:7.65485
# [550]	train-rmse:4.36411	valid-rmse:7.56254
# [600]	train-rmse:4.20695	valid-rmse:7.49706
# [650]	train-rmse:4.06757	valid-rmse:7.42192
# [700]	train-rmse:3.95067	valid-rmse:7.37561
# [750]	train-rmse:3.84321	valid-rmse:7.34347
# [800]	train-rmse:3.74771	valid-rmse:7.31929
# [850]	train-rmse:3.66255	valid-rmse:7.3018
# [900]	train-rmse:3.58296	valid-rmse:7.28341
# [950]	train-rmse:3.51254	valid-rmse:7.27058
# [1000]	train-rmse:3.44627	valid-rmse:7.26369
# [1050]	train-rmse:3.38267	valid-rmse:7.26047
# [1100]	train-rmse:3.3272	valid-rmse:7.25392
# [1150]	train-rmse:3.27347	valid-rmse:7.25394
# [1200]	train-rmse:3.22137	valid-rmse:7.25304
# Stopping. Best iteration:
# [1173]	train-rmse:3.24854	valid-rmse:7.25102

# %%
print(mean_absolute_error.__name__,"CV =",mean_absolute_error(train_pred,Y_train))
# Out:
# mean_absolute_error CV = 3.966874699951992
